# %%
# !pip install spacy 
# !pip install nltk 
! python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB 1.3 MB/s eta 0:00:10
#      ---------------------------------------- 0.1/12.8 MB 1.4 MB/s eta 0:00:09
#       --------------------------------------- 0.2/12.8 MB 2.0 MB/s eta 0:00:07
#       --------------------------------------- 0.2/12.8 MB 2.0 MB/s eta 0:00:07
#       --------------------------------------- 0.3/12.8 MB 1.1 MB/s eta 0:00:12
#       --------------------------------------- 0.3/12.8 MB 1.3 MB/s eta 0:00:10
#      - -------------------------------------- 0.5/12.8 MB 1.6 MB/s eta 0:00:08
#      - -------------------------------------- 0.6/12.8 MB 1.8 MB/s eta 0:00:07
#      -- ------------------------------------- 0.7/12.8 MB 1.6 MB/s eta 0:00:08
#      -- ------------------------------------- 0.7/12.8 MB 1.6 MB/s eta 0:00:08
#      -- ------------------------------------- 0.7/12.8 MB 1.5 MB/s eta 0:00:09
# ...

# %%
import pandas as pd 
import spacy 
import requests 
from bs4 import BeautifulSoup
nlp = spacy.load("en_core_web_sm")
#pd.set_option("display.max_rows", 200)

# %%
content = "Ram and Mohan are playing with a football in Sudama Stadium made by BJP."

doc = nlp(content)

for ent in doc.ents:
	print(ent.text, ent.label_)
# Out:
# Mohan PERSON
# Sudama Stadium FAC
# BJP ORG

# %%
from spacy import displacy
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ram and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mohan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  are playing with a football in
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sudama Stadium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  made by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BJP
# ...

# %%
entities = [(ent.text, ent.label_, ent.lemma_) for ent in doc.ents]
df = pd.DataFrame(entities, columns=['text', 'type', 'lemma'])
print(df)
# Out:
#                    text    type                 lemma
# 0              Congress     ORG              Congress
# 1          Mahua Moitra  PERSON          Mahua Moitra
# 2     the Supreme Court     ORG     the Supreme Court
# 3         the Lok Sabha  PERSON         the Lok Sabha
# 4                Moitra     ORG                Moitra
# 5            Parliament     ORG            Parliament
# 6             last week    DATE             last week
# 7  the Ethics Committee     ORG  the Ethics Committee
# 8   Darshan Hiranandani  PERSON   Darshan Hiranandani

# %%
from matplotlib import pyplot as plt

#import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
x=[1,2,3]
y=[1,4,6]

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.hist(x,bins)
plt.bar(x,height)
plt.pcolor(C)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plt.hist(x,bins)
#
# NameError: name 'bins' is not defined

# %%
sns.regplot(x = 'header_1',y = 'header_2',data= df)
sns.residplot(data=df,x='header_1', y='header_2')
Alternatively:
sns.residplot(x=df['header_1'], y=df['header_2'])
sns.kdeplot(X)
sns.distplot(X,hist=False)
# Out:
#   Cell In[15], line 3
#     Alternatively:
#                   ^
# SyntaxError: invalid syntax

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk
from nltk.tokenize import word_tokenize  # Import word_tokenize function
from nltk import pos_tag
text = "Ram and Mohan are playing with a football in Sudama Stadium."
tokens = word_tokenize(text) 
pos_tags = pos_tag(tokens)
print("Original Text:")
print(text)
print("\nPoS Tagging Result:")
for word, pos_tag in pos_tags:
    print(f"{word}: {pos_tag}")
# Out:
# Original Text:
# Ram and Mohan are playing with a football in Sudama Stadium.
#
# PoS Tagging Result:
# Ram: NNP
# and: CC
# Mohan: NNP
# are: VBP
# playing: VBG
# with: IN
# a: DT
# football: NN
# in: IN
# Sudama: NNP
# Stadium: NNP
# .: .

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
text = "Ram and Mohan are playing with a football in Sudama Stadium."
doc = nlp(text)
print("Original Text: ", text)
print(doc)

print("PoS Tagging Result:")
for token in doc:
    print(f"{token.text}: {token.pos_}: {token.tag_}")
# Out:
# Original Text:  Ram and Mohan are playing with a football in Sudama Stadium.
# Ram and Mohan are playing with a football in Sudama Stadium.
# PoS Tagging Result:
# Ram: PROPN: NNP
# and: CCONJ: CC
# Mohan: PROPN: NNP
# are: AUX: VBP
# playing: VERB: VBG
# with: ADP: IN
# a: DET: DT
# football: NOUN: NN
# in: ADP: IN
# Sudama: PROPN: NNP
# Stadium: PROPN: NNP
# .: PUNCT: .

# %% [markdown]
# While Hidden Markov Models (HMMs) have been explored for sentiment analysis, they are not the most common or necessarily the best approach. Here's a breakdown:
#
# Why HMMs Might Not Be Ideal:
#
# Sequence Classification:  Sentiment analysis often aims to classify an entire text as positive, negative, or neutral. HMMs are better suited for problems where you need to assign a label to each element in a sequence. For example, in speech recognition, an HMM might assign a specific phoneme (basic sound unit) to each segment of audio.
#
# Long-range Dependencies:  HMMs struggle to capture long-range dependencies in text. Sentiment can be influenced by words and phrases that appear far apart in a sentence.  HMMs typically focus on local relationships between adjacent elements in the sequence.
#
# Alternatives for Sentiment Analysis:
#
# Lexicon-Based Methods: These methods rely on pre-defined dictionaries of positive, negative, and neutral words to classify sentiment.
# Machine Learning Techniques: Techniques like Naive Bayes, Support Vector Machines (SVM), and Long Short-Term Memory (LSTM) networks are widely used and achieve high accuracy in sentiment analysis. These methods can handle long-range dependencies and complex relationships between words.
# However, if you're interested in exploring HMMs for sentiment analysis, here's a potential approach:
#
# State Definition: Define hidden states like "positive," "negative," and "neutral."
# Emission Probabilities: Calculate the probability of observing a word given each hidden state. This might involve using a sentiment lexicon or word embeddings.
# Transition Probabilities: Define the probability of transitioning between hidden states based on the sequence of words. For example, the probability of transitioning from "positive" to "negative" might be lower than vice versa.
# Decoding: Use the Viterbi algorithm to find the most likely sequence of hidden states (sentiment labels) for a given text input.
# Challenges and Considerations:
#
# Training the HMM requires labeled data where each sentence has a predefined sentiment label.
# Choosing the appropriate number of hidden states and defining emission/transition probabilities can be challenging.
# HMMs might not be as accurate as other methods for sentiment analysis.
# In conclusion, while HMMs offer a theoretical approach to sentiment analysis, they are not the preferred method due to their limitations. Explore lexicon-based methods or machine learning techniques like Naive Bayes or LSTMs for more practical and effective sentiment analysis solutions.

# %%
import numpy as np

# Define sentiment states
states = ("positive", "negative", "neutral")

# Sample transition probabilities (adjust these based on your analysis)
transition_matrix = np.array([
    [0.7, 0.2, 0.1],
    [0.1, 0.6, 0.3],
    [0.2, 0.2, 0.6]
])

# Example sentence (replace with your text)
sentence = "The movie was good, but the acting was a bit disappointing. This is a new release."

# Convert sentence to word list (lowercase and remove punctuation)
words = [word.lower().strip() for word in sentence.split()]

# Create word-to-index dictionary
word_to_index = {}
vocabulary_index = 0
for word in set(words):  # Use set() to get unique words
    if word not in word_to_index:
        word_to_index[word] = vocabulary_index
        vocabulary_index += 1

# Convert words to integer indices
word_indices = [word_to_index[word] for word in words]

# Initialize hidden state sequence (replace with random initialization if needed)
hidden_state_sequence = ["neutral"] * len(words)  # Assuming neutral sentiment initially

# Sample emission probabilities with padding for OOV words (assuming uniform distribution)
emission_matrix = np.random.rand(len(word_to_index), len(states))  # Initialize with random probabilities
emission_matrix /= emission_matrix.sum(axis=1, keepdims=True)  # Normalize rows to sum to 1

# Initialize hidden state sequence (replace with random initialization if needed)
hidden_state_sequence = ["neutral"] * len(words)  # Assuming neutral sentiment initially

# Implement Viterbi algorithm for decoding
def viterbi(words, states, transition_matrix, emission_matrix, word_to_index):
    """
    This function implements the Viterbi algorithm to find the most likely sequence of hidden states.
    """
    T = len(words)  # Number of words
    N = len(states)  # Number of states

    # Initialize DP tables
    dp = np.zeros((T, N))  # Stores probabilities of being in each state at each word
    psi = np.zeros((T, N), dtype=int)  # Stores backpointers for path reconstruction

    # Base case (first word)
    for i in range(N):
        if words[0] in word_to_index:
            word_index = word_to_index[words[0]]
            dp[0, i] = emission_matrix[word_index, i] * transition_matrix[i, 0]  # Initial state probability
        else:
            dp[0, i] = emission_matrix[-1, i] * transition_matrix[i, 0]  # Use default probability for OOV words

    # Dynamic programming
    for t in range(1, T):
        for i in range(N):
            # Find the most likely previous state and update probability and backpointer
            max_prob = -float('inf')
            for j in range(N):
                prob = dp[t-1, j] * transition_matrix[j, i]
                if words[t] in word_to_index:
                    word_index = word_to_index[words[t]]
                    prob *= emission_matrix[word_index, i]
                else:
                    prob *= emission_matrix[-1, i]  # Use default probability for OOV words
                if prob > max_prob:
                    max_prob = prob
                    psi[t, i] = j
            dp[t, i] = max_prob

    # Backtracking to find most likely hidden state sequence
    state_sequence = [None] * T
    state_sequence[T-1] = np.argmax(dp[T-1, :])
    for t in range(T-2, -1, -1):
        state_sequence[t] = psi[t+1, state_sequence[t+1]]

    return state_sequence

# Find the most likely hidden state sequence
hidden_state_sequence = viterbi(words, states, transition_matrix, emission_matrix, word_to_index)

# Print the result
for word, state in zip(words, hidden_state_sequence):
    print(f"{word}: {states[state]}")
# Out:
# the: positive
# movie: positive
# was: negative
# good,: negative
# but: negative
# the: negative
# acting: negative
# was: negative
# a: negative
# bit: negative
# disappointing.: neutral
# this: neutral
# is: neutral
# a: neutral
# new: neutral
# release.: neutral

# %%
import numpy as np

# Define sentiment states
states = ("positive", "negative", "neutral")

# Sample transition probabilities (adjust these based on your analysis)
transition_matrix = np.array([
    [0.7, 0.2, 0.1],
    [0.1, 0.6, 0.3],
    [0.2, 0.2, 0.6]
])

# Example sentence (replace with your text)
sentence = "The movie was good, but the acting was a bit disappointing. This is a new release."

# Convert sentence to word list (lowercase and remove punctuation)
words = [word.lower().strip() for word in sentence.split()]

# Create word-to-index dictionary
word_to_index = {}
vocabulary_index = 0
for word in set(words):
  word_to_index[word] = vocabulary_index
  vocabulary_index += 1

# Convert words to integer indices
word_indices = [word_to_index[word] for word in words]

# Initialize hidden state sequence (replace with random initialization if needed)
hidden_state_sequence = ["neutral"] * len(words)

# Sample emission probabilities with padding for OOV words (assuming uniform distribution)
emission_matrix = np.random.rand(len(word_to_index), len(states))
emission_matrix /= emission_matrix.sum(axis=1, keepdims=True)

# Implement Viterbi algorithm for decoding
def viterbi(words, states, transition_matrix, emission_matrix, word_to_index):
  T = len(words)
  N = len(states)

  # Initialize DP tables
  dp = np.zeros((T, N))
  psi = np.zeros((T, N), dtype=int)

  # Base case (first word)
  for i in range(N):
    if words[0] in word_to_index:
      word_index = word_to_index[words[0]]
      dp[0, i] = emission_matrix[word_index, i] * transition_matrix[i, 0]
    else:
      dp[0, i] = emission_matrix[-1, i] * transition_matrix[i, 0]

  # Dynamic programming
  for t in range(1, T):
    for i in range(N):
      max_prob = -float('inf')
      for j in range(N):
        prob = dp[t-1, j] * transition_matrix[j, i]
        if words[t] in word_to_index:
          word_index = word_to_index[words[t]]
          prob *= emission_matrix[word_index, i]
        else:
          prob *= emission_matrix[-1, i]
        if prob > max_prob:
          max_prob = prob
          psi[t, i] = j
      dp[t, i] = max_prob

  # Backtracking to find most likely hidden state sequence
  state_sequence = [None] * T
  state_sequence[T-1] = np.argmax(dp[T-1, :])
  for t in range(T-2, -1, -1):
    state_sequence[t] = psi[t+1, state_sequence[t+1]]

  return state_sequence

# Find the most likely hidden state sequence
hidden_state_sequence = viterbi(words, states, transition_matrix, emission_matrix, word_to_index)

# Print the result
for word, state in zip(words, hidden_state_sequence):
  print(f"{word}: {states[state]}")
# Out:
# the: neutral
# movie: neutral
# was: neutral
# good,: negative
# but: negative
# the: neutral
# acting: neutral
# was: neutral
# a: neutral
# bit: neutral
# disappointing.: neutral
# this: neutral
# is: neutral
# a: neutral
# new: positive
# release.: positive

# %%
import nltk
from collections import defaultdict
from itertools import repeat
tokenizer = nltk.TreebankWordTokenizer()    

alfa=0.1
zen=3

def prob(w,t,es,fs):
    if w in es[t]:
        return(float(es[t][w]+alfa)/(fs[w]+alfa*zen))
    else:
        return(float(alfa)/(fs[w]+alfa*zen))
    
def emisn(w,t,es,fs):
    if w in es[t]:
        return(float(es[t][w]+alfa)/(fs[t]+alfa*zen))
    else:
        return(float(alfa)/(fs[t]+alfa*zen))

def transn(t1,t2,ts,fs):
    if t2 in ts[t1]:
        return(float(ts[t1][t2]+alfa)/(fs[t1]+alfa*zen))
    else:
        return (float(alfa)/(fs[t1]+alfa*zen))
    
freqs = {}
tagfreqs={}
tags = defaultdict(dict)
trans = defaultdict(dict)

f=open('training_data.txt','rb')
text=f.read()
f.close()
lines = text.splitlines()
for line in lines:
    t=0
    if len(line.split(" "))<=1:
        continue
    tokens=line.split("\t")
    sen=tokens[0]
    tokens=tokens[1].split(" ")
    tokens.insert(0,"START")
    tokens.append("END")
    while t<len(tokens):
        try:
            freqs[tokens[t]]+=1
        except:
            freqs[tokens[t]]=1
        try:
            tagfreqs[sen]+=1
        except:
            tagfreqs[sen]=1
        try:
            tagfreqs["START"]+=1
        except:
            tagfreqs["START"]=1
        try:
            tags[sen][tokens[t]]+=1
        except:
            tags[sen][tokens[t]]=1
        t+=1
   
for line in lines:
    t=0
    if len(line.split(" "))<=1:
        continue
    tokens=line.split(" ")
    sen=tokens[0]
    st=["START"]
    tokens=tokens[1:]
    tokens.insert(0,"START")
    tokens.append("END")
    while t<len(tokens)-1:
        if tokens[t]=="START":
            z=max(tags.keys(), key=lambda tag:prob(tokens[t+1],tag,tags,freqs))
            try:
                trans["START"][z]+=1
            except:
                trans["START"][z]=1
        else:
            z=max(tags.keys(), key=lambda tag:prob(tokens[t+1],tag,tags,freqs))
            y=max(tags.keys(), key=lambda tag:prob(tokens[t],tag,tags,freqs))
            try:
                trans[y][z]+=1
            except:
                trans[y][z]=1            
        t+=1
    
print ("Training Completed")


# In[48]:

#Perform sentiment tagging based on trained HMM Model using Viterbi Algorithm
from collections import Counter

def viterbi(fs,es,ts,ft):
    total=0
    cfm=defaultdict(dict)
    f=open('test_data_no_true_labels.txt','rb')
    fw=open('submit.csv','wb')
    fw.write("id,answer\n")
    text=f.read()
    f.close()
    lines = text.splitlines()
    for line in lines:
        t=0
        if len(line.split(" "))<=1:
            continue
        tokens=line.split("\t")
        tokens=tokens[1].split(" ")
        tokens.insert(0,"START")
        tokens.append("END")
                
        viterbi = [ ]
        backpointer = [ ]
        first_viterbi = { }
        first_backpointer = { }
        for tag in es:
            if tag == "START":
                continue
            first_viterbi[tag] = transn("START",tag,ts,fs)*emisn(tokens[0],tag,es,fs)
            first_backpointer[tag] = "START"
        viterbi.append(first_viterbi)
        #print "check1"
        backpointer.append(first_backpointer)
        for i in range(1, len(tokens)-1):
            this_viterbi = { }
            this_backpointer = { }
            prev_viterbi = viterbi[-1]
            for tag in es:
                if tag == "START":
                    continue
                best_previous = max(prev_viterbi.keys(), key = lambda prevtag:prev_viterbi[prevtag]*transn(prevtag,tag,es,fs)*emisn(tokens[i],tag,es,fs))
                this_viterbi[tag] = prev_viterbi[best_previous]*transn(best_previous,tag,ts,fs)*emisn(tokens[i],tag,es,fs)
                this_backpointer[ tag ] = best_previous
            viterbi.append(this_viterbi)
            backpointer.append(this_backpointer)
        
        prev_viterbi = viterbi[-1]
        best_previous = max(prev_viterbi.keys(),key = lambda prevtag: prev_viterbi[prevtag]*transn(prevtag,"END",ts,fs))
        prob_tagsequence = prev_viterbi[ best_previous ]*transn(best_previous,"END",ts,fs)
        best_tagsequence = [ "END", best_previous ]
        
        backpointer.reverse()
        current_best_tag = best_previous
        for bp in backpointer:
            best_tagsequence.append(bp[current_best_tag])
            current_best_tag = bp[current_best_tag]
        best_tagsequence.reverse()
    
        if best_tagsequence[-2]=="neg":
            fw.write(str(total)+",-1"+"\n")
        elif best_tagsequence[-2]=="pos":
            fw.write(str(total)+",1"+"\n")
        else:
            fw.write(str(total)+",0"+"\n")
        total+=1
    fw.close()
    


# In[49]:

viterbi(tagfreqs,tags,trans,freqs)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 32
#      29 tags = defaultdict(dict)
#      30 trans = defaultdict(dict)
# ---> 32 f=open('training_data.txt','rb')
#      33 text=f.read()
#      34 f.close()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'training_data.txt'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.hmm import MultinomialHMM  # Import MultinomialHMM from hmm submodule

# Assuming you have your training and testing reviews stored in separate lists:
train_review = ["This movie was excellent!", "The acting was terrible.", "Overall, I enjoyed the film."]
test_review = ["I did not like the plot.", "The cinematography was beautiful."]

# Train-test split (adjust test_size as needed)
X_train, X_test, y_train, y_test = train_test_split(train_review, range(len(train_review)), test_size=0.2)  # Splitting labels along with reviews

# TF-IDF vectorization
vectorizer = TfidfVectorizer(norm=None)
x_train = vectorizer.fit_transform(X_train)
x_test = vectorizer.transform(X_test)

# Sequence lengths for training and testing data (assuming sentiment per review)
len_train_seq = np.ones((len(X_train), 1))  # Assuming each training review has length 1 (sentiment for whole review)
len_test_seq = np.ones((len(X_test), 1))  # Assuming each testing review has length 1 (sentiment for whole review)

# Multinomial HMM model for sentiment classification
model = MultinomialHMM()  # Create MultinomialHMM object
HMM_Classifier = model.fit(x_train, y_train, lengths=len_train_seq)

# Predict sentiment labels for test reviews
y_predict = HMM_Classifier.predict(x_test, lengths=len_test_seq)

# Evaluate model performance (optional)
accuracy = accuracy_score(y_test, y_predict)
print("Accuracy:", accuracy)

# Print predicted sentiment labels for test reviews (assuming your labels correspond to sentiment states)
for review, prediction in zip(X_test, y_predict):
  print(f"Review: {review}")
  print(f"Predicted Sentiment: {y_train[prediction]}")  # Using training labels for reference (modify if labels have different format)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 4
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn.metrics import accuracy_score
# ----> 4 from sklearn.hmm import MultinomialHMM  # Import MultinomialHMM from hmm submodule
#       6 # Assuming you have your training and testing reviews stored in separate lists:
#       7 train_review = ["This movie was excellent!", "The acting was terrible.", "Overall, I enjoyed the film."]
#
# ModuleNotFoundError: No module named 'sklearn.hmm'

# %%
pip install hmmlearn
# Out:
# ...
#   Obtaining dependency information for hmmlearn from https://files.pythonhosted.org/packages/6b/62/0c7b618eac6f27220baecdfe476259e005c690bf825d02a3cb8e5470bf2c/hmmlearn-0.3.2-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    --------- ------------------------------ 30.7/125.4 kB 1.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 112.6/125.4 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 125.4/125.4 kB 1.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn[hmm]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: scikit-learn 1.4.1.post1 does not provide the extra 'hmm'

# %%
# Importing libraries
import nltk
import numpy as np
import pandas as pd
import random
from sklearn.model_selection import train_test_split
import pprint, time
 
#download the treebank corpus from nltk
nltk.download('treebank')
 
#download the universal tagset from nltk
nltk.download('universal_tagset')
 
# reading the Treebank tagged sentences and storing into a list
nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))
 
#print the first two sentences along with tags
print(nltk_data[:2])

#print each word with its respective tag for first two sentences
# for sent in nltk_data[:2]:
#   for tuple in sent:
#     print(tuple)
    
# split data into training and testing set in the ratio 80:20
train_set,test_set =train_test_split(nltk_data,train_size=0.80,test_size=0.20,random_state = 101)

# create list of train and test tagged words
train_tagged_words = [ tup for sent in train_set for tup in sent ]
test_tagged_words = [ tup for sent in test_set for tup in sent ]
# print(len(train_tagged_words))
# print(len(test_tagged_words))

# check some of the tagged words.
train_tagged_words[:5]

#use set datatype to check how many unique tags are present in training data
tags = {tag for word,tag in train_tagged_words}
# print(len(tags))
# print(tags)
 
# check total words in vocabulary
vocab = {word for word,tag in train_tagged_words}

#! compute Emission Probability
print("\nCalculating Emission Probablity...")
def word_given_tag(word, tag, train_bag = train_tagged_words):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)#total number of times the passed tag occurred in train_bag
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
#now calculate the total number of times the passed word occurred as the passed tag.
    count_w_given_tag = len(w_given_tag_list)
 
    return (count_w_given_tag, count_tag)

print("Calculating Transmission Probablity...")
#! compute  Transition Probability
def t2_given_t1(t2, t1, train_bag = train_tagged_words):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

#! creating t x t transition matrix of tags, t= no of tags
# Matrix(i, j) represents P(jth tag after the ith tag)
 
tags_matrix = np.zeros((len(tags), len(tags)), dtype='float32')
for i, t1 in enumerate(list(tags)):
    for j, t2 in enumerate(list(tags)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]
 
# print(tags_matrix)

# convert the matrix to a df for better readability
#the table is same as the transition table shown in section 3 of article
tags_df = pd.DataFrame(tags_matrix, columns = list(tags), index=list(tags))
print(tags_df)


# Let's test our Viterbi algorithm on a few sample sentences of test dataset
random.seed(1234)      #define a random seed to get same sentences when run multiple times
 
# choose random 10 numbers
rndom = [random.randint(1,len(test_set)) for x in range(10)]
 
# list of 10 sents on which we test the model
test_run = [test_set[i] for i in rndom]
 
# list of tagged words
test_run_base = [tup for sent in test_run for tup in sent]
 
# list of untagged words
test_tagged_words = [tup[0] for sent in test_run for tup in sent]



#To improve the performance,we specify a rule base tagger for unknown words 
# specify patterns for tagging
patterns = [
    (r'.*ing$', 'VERB'),              # gerund
    (r'.*ed$', 'VERB'),               # past tense 
    (r'.*es$', 'VERB'),               # verb    
    (r'.*\'s$', 'NOUN'),              # possessive nouns
    (r'.*s$', 'NOUN'),                # plural nouns
    (r'\*T?\*?-[0-9]+$', 'X'),        # X
    (r'^-?[0-9]+(.[0-9]+)?$', 'NUM'), # cardinal numbers
    (r'.*', 'NOUN')                   # nouns
]
 
# rule based tagger
rule_based_tagger = nltk.RegexpTagger(patterns)

print("\nRunning Viterbi Algorithm...")
#modified Viterbi to include rule based tagger in it
def Viterbi_rule_based(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
     
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                 
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
             
        pmax = max(p)
        state_max = rule_based_tagger.tag([word])[0][1]       
        
         
        if(pmax==0):
            state_max = rule_based_tagger.tag([word])[0][1] # assign based on rule based tagger
        else:
            if state_max != 'X':
                # getting state for which probability is maximum
                state_max = T[p.index(pmax)]                
             
         
        state.append(state_max)
    return list(zip(words, state))

#test accuracy on subset of test data 
start = time.time()
tagged_seq = Viterbi_rule_based(test_tagged_words)
end = time.time()
difference = end-start
 
print("\nTime taken in seconds: ", round(difference,2))
 
# accuracy
check = [i for i, j in zip(tagged_seq, test_run_base) if i == j] 
 
accuracy = len(check)/len(tagged_seq)
print('Viterbi Algorithm Accuracy: ',round(accuracy*100,2))

#Check how a sentence is tagged by the two POS taggers
#and compare them
test_sent="Will can see Marry"
pred_tags_rule=Viterbi_rule_based(test_sent.split())

print(pred_tags_rule)
#Will and Marry are tagged as NUM as they are unknown words for Viterbi Algorithm
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\treebank.zip.
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\universal_tagset.zip.
# [[('Pierre', 'NOUN'), ('Vinken', 'NOUN'), (',', '.'), ('61', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), (',', '.'), ('will', 'VERB'), ('join', 'VERB'), ('the', 'DET'), ('board', 'NOUN'), ('as', 'ADP'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('Nov.', 'NOUN'), ('29', 'NUM'), ('.', '.')], [('Mr.', 'NOUN'), ('Vinken', 'NOUN'), ('is', 'VERB'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Elsevier', 'NOUN'), ('N.V.', 'NOUN'), (',', '.'), ('the', 'DET'), ('Dutch', 'NOUN'), ('publishing', 'VERB'), ('group', 'NOUN'), ('.', '.')]]
#
# Calculating Emission Probablity...
# Calculating Transmission Probablity...
# ...
